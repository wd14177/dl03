# %%
# lib import
print("Importing libraries...")
import torch
import torch.nn as nn
import torchvision
from torchvision import transforms, datasets, models
print("Libraries imported successfully.")


# cuda available check
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('mps') if torch.backends.mps.is_available() else torch.device('cpu')
print(f'Using device: {device}')
# Out:
# Importing libraries...
# Libraries imported successfully.
# Using device: cuda

# %%
# model load
model = models.resnet34(pretrained=True)

# model load "best_model.pth", fc layer output 3
num_classes = 3
model.fc = nn.Linear(model.fc.in_features, num_classes)
model.load_state_dict(torch.load('best_model.pth', map_location=device))

# model to device
model = model.to(device)

# %%
# test transform
test_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# %%
# uuid test
import uuid

for i in range(5):
    print(f'Generated UUID: {uuid.uuid4()}')
# Out:
# Generated UUID: db05e6a1-4cf1-4b6c-a5a6-becd94c9ba26
# Generated UUID: 0f069166-7887-4f09-884e-d981845b617b
# Generated UUID: 2147c3d7-8ccc-48c0-86f5-afef8620be44
# Generated UUID: 088c5393-2288-4d68-b2e7-e78bf6995daa
# Generated UUID: 9ea0bdcc-f0a6-42d8-adb5-6ee04c0ae020
