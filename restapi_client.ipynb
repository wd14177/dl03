# %%
print("hello world")
# Out:
# hello world

# %%
import requests
url = "http://localhost:8000/infer"

with open("data/img/test_img.jpg", "rb") as f:
    response = requests.post(url, files={"file": f})
print(response.status_code)
response.json()
# Out:
# 200
# {'result': 'Amanda Seyfried',
#  'index': 0,
#  'filename': 'e66628a7-1df3-4700-bf21-07584a0cb322.jpg',
#  'model_class': 'Amanda Seyfried'}
